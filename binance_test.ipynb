# %%
#pip install python-binance
from binance.client import Client
from binance.enums import *
import time

# %%
#Connect Binance
API_Key= 'aOEKL7yCQ28tJJpjMwMzM2LclNcp2kulXbGK77UfT6xc2f8Dr5iShGS1sczwIzUH'
Secret_Key= 'lmQ29djwYzmaTPcz9v5LVr5sJPZfuTTwCnOCGdjIKg8VHGjaZ58viPL2i7rhnrbK'
client = Client(API_Key,Secret_Key,testnet= True)

# %%
ticker = client.get_all_tickers()
print(ticker)
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.02193000'}, {'symbol': 'LTCBTC', 'price': '0.00099900'}, {'symbol': 'BNBBTC', 'price': '0.00723400'}, {'symbol': 'BTCUSDT', 'price': '81338.75000000'}, {'symbol': 'ETHUSDT', 'price': '1787.79000000'}, {'symbol': 'TRXBTC', 'price': '0.00000285'}, {'symbol': 'XRPBTC', 'price': '0.00002509'}, {'symbol': 'BNBUSDT', 'price': '589.70000000'}, {'symbol': 'LTCUSDT', 'price': '81.45000000'}, {'symbol': 'LTCBNB', 'price': '0.13800000'}, {'symbol': 'XRPUSDT', 'price': '2.04570000'}, {'symbol': 'XRPBNB', 'price': '0.00346830'}, {'symbol': 'TRXBNB', 'price': '0.00039450'}, {'symbol': 'TRXUSDT', 'price': '0.23260000'}, {'symbol': 'NEOBTC', 'price': '0.00006120'}, {'symbol': 'QTUMETH', 'price': '0.00106900'}, {'symbol': 'EOSETH', 'price': '0.00033760'}, {'symbol': 'SNTETH', 'price': '0.00001256'}, {'symbol': 'GASBTC', 'price': '0.00003000'}, {'symbol': 'BNBETH', 'price': '0.32990000'}, {'symbol': 'LRCBTC', 'price': '0.00000118'}, {'symbol': 'LRCETH', 'price': '0.00
# ...

# %%
# Fetch historical trades for a specific symbol
def get_historical_trades(symbol, limit=10):
    try:
        response = client.futures_historical_trades(symbol=symbol, limit=limit)
        print("Historical Trades:", response)
    except Exception as e:
        print("Error:", e)

# Example: Fetch historical trades for BTCUSD
get_historical_trades(symbol="BTCUSDT",limit=5)
# Out:
# Historical Trades: [{'id': 319728523, 'price': '82193.80', 'qty': '60.713', 'quoteQty': '4990232.17', 'time': 1743409528224, 'isBuyerMaker': False}, {'id': 319728524, 'price': '82193.80', 'qty': '11.106', 'quoteQty': '912844.34', 'time': 1743409528224, 'isBuyerMaker': False}, {'id': 319728525, 'price': '82199.90', 'qty': '26.760', 'quoteQty': '2199669.32', 'time': 1743409528224, 'isBuyerMaker': False}, {'id': 319728526, 'price': '82200.10', 'qty': '0.002', 'quoteQty': '164.40', 'time': 1743409528224, 'isBuyerMaker': False}, {'id': 319728527, 'price': '82200.20', 'qty': '43.380', 'quoteQty': '3565844.67', 'time': 1743409528224, 'isBuyerMaker': False}]

# %%
import datetime
res = client.get_server_time()
ts = res['serverTime'] / 1000
your_dt = datetime.datetime.fromtimestamp(ts)
your_dt.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2025.03.31 10:39:55'

# %%
# Check account balance
account_info = client.get_account()
# # print("Account Balance:", account_info['balances'])
# client.ping()
account_info
# Out:
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00000000',
#   'taker': '0.00000000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1743193433047,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'ETH', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '0.99900000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '4.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '10083.93198000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '2059.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '201.00000000', 'locked': '0.00000000'},
# ...

# %%
symbol = "BTCUSDT"
buy_price_threshold = 60000
sell_price_threshold = 68000
trade_quantity = 0.001

# %%
def get_current_price(symbol):
    ticker = client.get_symbol_ticker(symbol=symbol)
    return float(ticker['price'])

# %%
get_current_price(symbol)
# Out:
# 81534.53

# %%
# client.create_test_order(symbol = symbol,quantity = quantity,type = "MARKET",side = side)
def place_buy_order(symbol, quantity):
    try:
        return client.order_market_buy(symbol = symbol,quantity = quantity)
        
    except:
        print("could'nt Open an order!")


def place_sell_order(symbol, quantity):
    try:
        return client.order_market_sell(symbol = symbol,quantity = quantity)
        
    except:
        print("could'nt Open an order!")

def close_order(order):
    print(client.cancel_order(
    symbol=order['symbol'],
    orderId=order['orderId']
))
def order_status(order):
    print(client.get_order(symbol=order['symbol'],orderId=order['orderId']))

# %%
#order =place_buy_order(symbol,trade_quantity)
order_status(order)
# #help(client.futures_get_all_orders)
# client.order_market_buy(symbol = "BTCUSDT", quantity = 0.005, newClientOrderId = "1")
# # client.futures_api_trading_status()
# # help(client.create_test_order())
#client.create_test_order(symbol = "BTCUSDT", quantity = trade_quantity , type = "MARKET", side = "BUY")
# Out:
# {'symbol': 'BTCUSDT', 'orderId': 12422077, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJf88f51d8674bae15af3179', 'price': '0.00000000', 'origQty': '0.00100000', 'executedQty': '0.00100000', 'cummulativeQuoteQty': '82.17987000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'stopPrice': '0.00000000', 'icebergQty': '0.00000000', 'time': 1743424881067, 'updateTime': 1743424881067, 'isWorking': True, 'workingTime': 1743424881067, 'origQuoteOrderQty': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %%
place_sell_order(symbol,trade_quantity)
# Out:
# Sell order done: {'symbol': 'BTCUSDT', 'orderId': 11236308, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ4eb36aff3ca7b6bb6768c', 'transactTime': 1743193433047, 'price': '0.00000000', 'origQty': '0.00100000', 'executedQty': '0.00100000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '83.97544000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'workingTime': 1743193433047, 'fills': [{'price': '83975.44000000', 'qty': '0.00100000', 'commission': '0.00000000', 'commissionAsset': 'USDT', 'tradeId': 2575253}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %%
#client.get_all_orders(symbol = symbol)
print(dir(client))
#client.cancel_all_open_orders(symbol)
# Out:
# ['AGG_BEST_MATCH', 'AGG_BUYER_MAKES', 'AGG_FIRST_TRADE_ID', 'AGG_ID', 'AGG_LAST_TRADE_ID', 'AGG_PRICE', 'AGG_QUANTITY', 'AGG_TIME', 'API_KEY', 'API_SECRET', 'API_TESTNET_URL', 'API_URL', 'BASE_ENDPOINT_1', 'BASE_ENDPOINT_2', 'BASE_ENDPOINT_3', 'BASE_ENDPOINT_4', 'BASE_ENDPOINT_DEFAULT', 'COIN_FUTURE_TO_SPOT', 'CONTRACT_ORDER_PREFIX', 'FIAT_TO_MINING', 'FIAT_TO_SPOT', 'FIAT_TO_USDT_FUTURE', 'FUTURES_API_VERSION', 'FUTURES_API_VERSION2', 'FUTURES_API_VERSION3', 'FUTURES_COIN_DATA_TESTNET_URL', 'FUTURES_COIN_DATA_URL', 'FUTURES_COIN_TESTNET_URL', 'FUTURES_COIN_URL', 'FUTURES_DATA_TESTNET_URL', 'FUTURES_DATA_URL', 'FUTURES_TESTNET_URL', 'FUTURES_URL', 'FUTURE_ORDER_TYPE_LIMIT', 'FUTURE_ORDER_TYPE_LIMIT_MAKER', 'FUTURE_ORDER_TYPE_MARKET', 'FUTURE_ORDER_TYPE_STOP', 'FUTURE_ORDER_TYPE_STOP_MARKET', 'FUTURE_ORDER_TYPE_TAKE_PROFIT', 'FUTURE_ORDER_TYPE_TAKE_PROFIT_MARKET', 'KLINE_INTERVAL_12HOUR', 'KLINE_INTERVAL_15MINUTE', 'KLINE_INTERVAL_1DAY', 'KLINE_INTERVAL_1HOUR', 'KLINE_INTERVAL_1MINUTE
# ...

# %%
#print(help(client.cancel_order()))
#client.cancel_order(symbol = symbol,orderId = 11221184 )
